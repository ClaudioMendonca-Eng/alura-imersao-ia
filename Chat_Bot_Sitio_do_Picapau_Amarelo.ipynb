# %% [markdown]
# <a href="https://colab.research.google.com/github/ClaudioMendonca-Eng/alura-imersao-ia/blob/main/Chat_Bot_Sitio_do_Picapau_Amarelo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####« Mais detalhes da configuração
# <center><a href="https://www.alura.com.br/" target="_blank"><img style="margin: 10px" height="150" width="500" src="https://github.com/ClaudioMendonca-Eng/alura-imersao-ia/raw/main/img/logo_imersao.png" alt="Alura logo"/></a></center>
# <center><img src='https://upload.wikimedia.org/wikipedia/commons/thumb/4/45/Gemini_language_model_logo.png/200px-Gemini_language_model_logo.png' height="120" alt="Gemini-logo"/></center>
#
# <center><h3>Configuração do API Gemini</h3></center><br>
# <h1>⏬ DEPOIS DAS CONFIGURAÇÕES EXECUTE AQUI!!</h1>

# %%
#@title Instalando o SDK do Google Gemini
# @markdown #### ⬅️ EXECUTE AQUI!! - Instalando o SDK do Google Gemini
# !pip install -q -U google-generativeai

# %%
#@title Configuração do API Gemini
# @markdown #### ⬅️ EXECUTE AQUI!!
#@markdown <center><h1>Configuração do API Gemini</h1></center><br>

#@markdown Configurações:<br>&emsp;[Por favor, insira a sua API Key:](https://aistudio.google.com/app/apikey/?utm_source=website&utm_medium=referral&utm_campaign=Alura&utm_content=)
API_KEY = "Por favor, insira a sua API Key" # @param {type:"string"}

import google.generativeai as genai

GOOGLE_API_KEY = API_KEY

def mostrar_parametros_seguranca(parametros):
    seguranca = {
        "Bloquear nenhum": "BLOCK_NONE",
        "Bloquear poucos": "BLOCK_ONLY_HIGH",
        "Bloquear alguns": "BLOCK_MEDIUM_AND_ABOVE",
        "Bloquear muitos": "BLOCK_LOW_AND_ABOVE"
    }
    if parametros in seguranca:
        return seguranca[parametros]
    else:
        return "Personagem não encontrado"
ASSEDIO = "Bloquear nenhum" # @param ["Bloquear nenhum", "Bloquear poucos", "Bloquear alguns", "Bloquear muitos"]
HARASSMENT = mostrar_parametros_seguranca(ASSEDIO)
ODIO = "Bloquear nenhum" # @param ["Bloquear nenhum", "Bloquear poucos", "Bloquear alguns", "Bloquear muitos"]
HATE = mostrar_parametros_seguranca(ODIO)
SEXUAL = "Bloquear nenhum" # @param ["Bloquear nenhum", "Bloquear poucos", "Bloquear alguns", "Bloquear muitos"]
SEXY = mostrar_parametros_seguranca(SEXUAL)
PERIGOSO = "Bloquear nenhum" # @param ["Bloquear nenhum", "Bloquear poucos", "Bloquear alguns", "Bloquear muitos"]
DANGEROUS = mostrar_parametros_seguranca(PERIGOSO)

safety_settings = {
    "HARASSMENT": HARASSMENT,
    "HATE": HATE,
    "SEXUAL": SEXY,
    "DANGEROUS": DANGEROUS,
}

def validar_api_key(api_key):
  """Verifica se a API Key é válida tentando listar os modelos disponíveis."""
  genai.configure(api_key=api_key)
  try:
    model = genai.GenerativeModel('gemini-pro')
    response = model.generate_content("So para testa a API Key! resposta simples A API Key é valida!")
    if response.text == "API Key válida!":
      print(response.text)
      return True
    else:
      print("Nenhum modelo encontrado. Verifique sua chave de API.")
      return False
  except Exception as e:
    print(f"Erro ao validar a API Key: {e}")
    return False


# Testa a API Key
if validar_api_key(GOOGLE_API_KEY):
  print("Pronto para usar a API!")
else:
  print("Verifique a API Key e tente novamente.")

# %% [markdown]
# # CHAT BOT - SITIO DO PICAPAU AMARELO
# <br><center><img src='https://i2.wp.com/sitio.pmvs.pt/wp-content/uploads/2014/06/cropped-11704119222.jpg' height="300" alt="Gemini-logo"/></center>
#
# > DIREITOS AUTORAIS - DOMÍNIO PÚBLICO
# >
# > Explore as infinitas possibilidades e divirta-se com as aventuras do Sítio do Picapau Amarelo!
# > Compartilhe essa informação com seus amigos e familiares para que todos possam aproveitar essa oportunidade incrível!
# <details>
#   <summary>Mais detalhes</summary>
#   O Sítio do Picapau Amarelo em Domínio Público: Uma Aventura Aberta à Todos!
#
#   As obras de Monteiro Lobato, incluindo o Sítio do Picapau Amarelo, entraram em domínio público no dia 1º de janeiro de 2019! Isso significa que você é livre para:
#
#   - Ler, reler e compartilhar as histórias com quem quiser.
#   - Adaptar as obras para outros formatos, como peças de teatro, filmes, músicas e até mesmo jogos.
#   - Publicar as obras em qualquer plataforma, seja online ou impressa.
#   - Traduzir as histórias para outros idiomas e levar a magia do Sítio para o mundo todo.
#   - Criar novas obras usando os personagens e elementos do Sítio, dando vida a novas aventuras.
#
#   Mas atenção:
#
#   - As ilustrações originais dos livros ainda são protegidas por direitos autorais. Para usá-las, você precisará obter a permissão dos detentores dos direitos.
#   - É sempre importante citar a fonte quando utilizar qualquer material do Sítio do Picapau Amarelo, mesmo que a obra esteja em domínio público.
# </details>

# %%
# ============================= FORM ============================= #
# @markdown #### ⬅️ EXECUTE O CHAT AQUI!!
#@title Configuração do CHATBOT
#@markdown <center><h3>CHAT COM OS PERSONAGEM </h3></center><br>


import textwrap
from IPython.display import display
from IPython.display import Markdown

# Melhorando a visualização
def to_markdown(text):
    text = text.replace('.', '\n')
    return Markdown(textwrap.indent(text,
                                     prefix='## ',
                                     predicate=lambda x: True))

def mostrar_personalidade(personagem):
    personalidades = {
        "Cuca": "Seja o personagem Cuca do Sítio do Picapau Amarelo: Aterrorizante e ardilosa, a Cuca é a personificação do medo no Sítio do Picapau Amarelo. Com sua aparência assustadora e seu jeito malvado, ela espalha terror por onde passa, sempre tramando planos nefastos para conseguir o que deseja.",
        "Dona Benta": "Seja o personagem Dona Benta do Sítio do Picapau Amarelo: Sábia e experiente: Dona Benta é a matriarca do Sítio e uma fonte de sabedoria para todos os personagens. Ela tem uma vasta experiência de vida e sempre sabe o que fazer nas situações mais difíceis. Carinhosa e acolhedora: Dona Benta tem um coração bondoso e acolhedor. Ela trata todos com carinho e respeito, e sempre está disposta a oferecer um ombro amigo para quem precisa. Justa e honesta: Dona Benta acredita na justiça e na honestidade, e sempre ensina seus netos a serem pessoas boas e honestas. Paciente e compreensiva: Dona Benta é uma pessoa paciente e compreensiva, que sabe lidar com as travessuras de seus netos e amigos. Líder inspiradora: Dona Benta é uma líder inspiradora que guia e aconselha os personagens do Sítio. Ela é um exemplo de força, sabedoria e bondade para todos.",
        "Zé Carneiro": "Seja o personagem Zé Carneiro do Sítio do Picapau Amarelo: Guloso e preguiçoso, Zé Carneiro é o porco do Sítio do Picapau Amarelo. Com sua paixão por comida e sua tendência a procrastinar, ele representa o lado indulgente e preguiçoso de muitos de nós, sempre em busca de conforto e prazer imediato."
    }

    if personagem in personalidades:
        return personalidades[personagem]
    else:
        return "Personagem não encontrado"

#@markdown Configurações:<br>&emsp;Por favor, digite seu nome para que eu possa conhecê-lo(a) melhor:
Nome = "Por favor, digite seu nome" # @param {type:"string"}
#@markdown <br>&emsp;Escolha o Personagem do Sítio para Conversar:
Personagem = "Emília" # @param ["Cuca", "Dona Benta", "Emília", "Narizinho", "Pedrinho", "Saci Pererê", "Tia Nastácia", "Visconde de Sabugosa", "Zé Carneiro"]
Personalidade = mostrar_personalidade(Personagem)
#@markdown Observação:<br>&emsp;Quando quiser encerrar o chat, basta digitar **"fim"**.


generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 0,
  "max_output_tokens": 8192,
}
system_instruction = f"{Personalidade} Sabendo que eu sou {Nome} uma pessoa que vc acabou de conhecer!"

model = genai.GenerativeModel(model_name="gemini-1.5-pro-latest",
                              generation_config=generation_config,
                              system_instruction=system_instruction,
                              safety_settings=safety_settings)

print('=============================================================================================================================================================================')
print('███████╗██╗████████╗██╗ ██████╗     ██████╗  ██████╗     ██████╗ ██╗ ██████╗ █████╗ ██████╗  █████╗ ██╗   ██╗     █████╗ ███╗   ███╗ █████╗ ██████╗ ███████╗██╗      ██████╗ ')
print('██╔════╝██║╚══██╔══╝██║██╔═══██╗    ██╔══██╗██╔═══██╗    ██╔══██╗██║██╔════╝██╔══██╗██╔══██╗██╔══██╗██║   ██║    ██╔══██╗████╗ ████║██╔══██╗██╔══██╗██╔════╝██║     ██╔═══██╗')
print('███████╗██║   ██║   ██║██║   ██║    ██║  ██║██║   ██║    ██████╔╝██║██║     ███████║██████╔╝███████║██║   ██║    ███████║██╔████╔██║███████║██████╔╝█████╗  ██║     ██║   ██║')
print('╚════██║██║   ██║   ██║██║   ██║    ██║  ██║██║   ██║    ██╔═══╝ ██║██║     ██╔══██║██╔═══╝ ██╔══██║██║   ██║    ██╔══██║██║╚██╔╝██║██╔══██║██╔══██╗██╔══╝  ██║     ██║   ██║')
print('███████║██║   ██║   ██║╚██████╔╝    ██████╔╝╚██████╔╝    ██║     ██║╚██████╗██║  ██║██║     ██║  ██║╚██████╔╝    ██║  ██║██║ ╚═╝ ██║██║  ██║██║  ██║███████╗███████╗╚██████╔╝')
print('╚══════╝╚═╝   ╚═╝   ╚═╝ ╚═════╝     ╚═════╝  ╚═════╝     ╚═╝     ╚═╝ ╚═════╝╚═╝  ╚═╝╚═╝     ╚═╝  ╚═╝ ╚═════╝     ╚═╝  ╚═╝╚═╝     ╚═╝╚═╝  ╚═╝╚═╝  ╚═╝╚══════╝╚══════╝ ╚═════╝ ')
print('=============================================================================================================================================================================')
print(f'Por favor, digite uma pergunta para {Personagem}: ')
print('---------------------------------------------')

chat = model.start_chat(history=[])
prompt = input(f"{Nome}: ")

while prompt != "fim":
  response = chat.send_message(prompt)
  # Melhorando a visualização
  # Imprimindo o final histórico
  if chat.history:
    last_message = chat.history[-1]
    display(to_markdown(f'**{Personagem}**: {last_message.parts[0].text}'))
    print('---------------------------------------------')

  prompt = input(f"{Nome}: ")

# Melhorando a visualização
# Imprimindo Resumo do histórico
for message in chat.history:
    if message.role == "user":
      display(to_markdown(f'**{Nome}**: {message.parts[0].text}'))
      print('------------------')
    else:
        display(to_markdown(f'**{Personagem}**: {message.parts[0].text}'))
        print('------------------')

# %%
# @markdown #### ⬅️ EXECUTE AQUI!! - Histórico da última conversa
#@title Configuração do API Gemini
import textwrap
from IPython.display import display
from IPython.display import Markdown

# Melhorando a visualização
def to_markdown(text):
    text = text.replace('.', '\n')
    return Markdown(textwrap.indent(text,
                                     prefix='## ',
                                     predicate=lambda x: True))
if chat.history != []:
  print('=============================================================================================================================================================================')
  print('███████╗██╗████████╗██╗ ██████╗     ██████╗  ██████╗     ██████╗ ██╗ ██████╗ █████╗ ██████╗  █████╗ ██╗   ██╗     █████╗ ███╗   ███╗ █████╗ ██████╗ ███████╗██╗      ██████╗ ')
  print('██╔════╝██║╚══██╔══╝██║██╔═══██╗    ██╔══██╗██╔═══██╗    ██╔══██╗██║██╔════╝██╔══██╗██╔══██╗██╔══██╗██║   ██║    ██╔══██╗████╗ ████║██╔══██╗██╔══██╗██╔════╝██║     ██╔═══██╗')
  print('███████╗██║   ██║   ██║██║   ██║    ██║  ██║██║   ██║    ██████╔╝██║██║     ███████║██████╔╝███████║██║   ██║    ███████║██╔████╔██║███████║██████╔╝█████╗  ██║     ██║   ██║')
  print('╚════██║██║   ██║   ██║██║   ██║    ██║  ██║██║   ██║    ██╔═══╝ ██║██║     ██╔══██║██╔═══╝ ██╔══██║██║   ██║    ██╔══██║██║╚██╔╝██║██╔══██║██╔══██╗██╔══╝  ██║     ██║   ██║')
  print('███████║██║   ██║   ██║╚██████╔╝    ██████╔╝╚██████╔╝    ██║     ██║╚██████╗██║  ██║██║     ██║  ██║╚██████╔╝    ██║  ██║██║ ╚═╝ ██║██║  ██║██║  ██║███████╗███████╗╚██████╔╝')
  print('╚══════╝╚═╝   ╚═╝   ╚═╝ ╚═════╝     ╚═════╝  ╚═════╝     ╚═╝     ╚═╝ ╚═════╝╚═╝  ╚═╝╚═╝     ╚═╝  ╚═╝ ╚═════╝     ╚═╝  ╚═╝╚═╝     ╚═╝╚═╝  ╚═╝╚═╝  ╚═╝╚══════╝╚══════╝ ╚═════╝ ')
  print('=============================================================================================================================================================================')
  print(f'Histórico da última conversa com {Personagem}: ')
  print('---------------------------------------------')
else:
  print('---------------------------------------------')
  print('---------------  SEM HISTORICO  -------------')
  print('---------------------------------------------')

# Imprimindo o histórico
for message in chat.history:
    if message.role == "user":
      display(to_markdown(f'**{Nome}**: {message.parts[0].text}'))
      print('------------------------------------------------------------------------------------------------------------')
    else:
        display(to_markdown(f'**{Personagem}**: {message.parts[0].text}'))
        print('------------------------------------------------------------------------------------------------------------')

# %% [markdown]
# #Licença
#
# Copyright © 2024 <a href="https://www.claudiomendonca.eng.br" target="_blank">ClaudioMendonca.eng.br</a>. Projeto <a href="https://github.com/ClaudioMendonca-Eng/alura-imersao-ia" target="_blank">GitHub</a>
